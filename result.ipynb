# %% [markdown]
# #  Result<br>

# %% [markdown]
# ### import

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from function import Affine
from function import Sigmoid
from function import Softmax
from function import MLP
from optimizer import SGD
from train import train

# %% [markdown]
# ### シンプルなMLPの結果<br>
#
#
# <ul>
# <li>weightの初期値はheの初期値を使用
# <li>optimzerは確率的勾配法(SGD)を使用
# <li>trainデータは60,000、testデータは10,000
# <li>線形層は3層(784→1000→1000→10)
# <li>活性化関数はsigmoid関数を利用
# <li>学習係数は0.1
# </ul>
#
# <text>
# 結果は、accuracyが95%くらいに落ち着いた。
# </text>

# %%
optimizer_sgd = SGD(0.1)
model= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
optimizer_sgd.set(model)

# %%
train_loss_list, train_acc_list, test_loss_list, test_acc_list = train(model, optimizer_sgd,error_ratio=0)

# %%
### trainデータの訓練結果

plt.plot(np.arange(len(train_acc_list)),np.asarray(train_acc_list),label = "train")
plt.plot(np.arange(len(test_acc_list)),np.asarray(test_acc_list),label = "test")

plt.xlabel("epoch")
plt.ylabel("accuracy")

plt.legend()
plt.show()

# %% [markdown]
# ### 入力データに誤差を入れた時の結果

# %%
optimizer_sgd_0 = SGD(0.5)
optimizer_sgd_5 = SGD(0.5)
optimizer_sgd_10 = SGD(0.5)
optimizer_sgd_15 = SGD(0.5)
optimizer_sgd_20 = SGD(0.5)
optimizer_sgd_25 = SGD(0.5)

model_0= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_5= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_10= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_15= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_20= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_25= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])

optimizer_sgd_0.set(model_0)
optimizer_sgd_5.set(model_5)
optimizer_sgd_10.set(model_10)
optimizer_sgd_15.set(model_15)
optimizer_sgd_20.set(model_20)
optimizer_sgd_25.set(model_25)

# %%
### 誤差による結果を求める
train_loss_list_error_0, train_acc_list_error_0, test_loss_list_error_0, test_acc_list_error_0 = train(model_0, optimizer_sgd_0,error_ratio=0)
train_loss_list_error_5, train_acc_list_error_5, test_loss_list_error_5, test_acc_list_error_5 = train(model_5, optimizer_sgd_5,error_ratio=0.05)
train_loss_list_error_10, train_acc_list_error_10, test_loss_list_error_10, test_acc_list_error_10 = train(model_10, optimizer_sgd_10,error_ratio=0.10)
train_loss_list_error_15, train_acc_list_error_15, test_loss_list_error_15, test_acc_list_error_15 = train(model_15, optimizer_sgd_15,error_ratio=0.15)
train_loss_list_error_20, train_acc_list_error_20, test_loss_list_error_20, test_acc_list_error_20 = train(model_20, optimizer_sgd_20,error_ratio=0.20)
train_loss_list_error_25, train_acc_list_error_25, test_loss_list_error_25, test_acc_list_error_25 = train(model_25, optimizer_sgd_25,error_ratio=0.25)

# %%
### trainデータの訓練結果

plt.plot(np.arange(len(train_acc_list_error_0)),np.asarray(train_acc_list_error_0),label = "train(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_error_5)),np.asarray(train_acc_list_error_5),label = "train(error_raito=0.05)")
plt.plot(np.arange(len(train_acc_list_error_10)),np.asarray(train_acc_list_error_10),label = "train(error_raito=0.10)")
plt.plot(np.arange(len(train_acc_list_error_15)),np.asarray(train_acc_list_error_15),label = "train(error_raito=0.15)")
plt.plot(np.arange(len(train_acc_list_error_20)),np.asarray(train_acc_list_error_20),label = "train(error_raito=0.20)")
plt.plot(np.arange(len(train_acc_list_error_25)),np.asarray(train_acc_list_error_25),label = "train(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("train data")

plt.legend()
plt.show()

# %%
### 訓練データの訓練結果

plt.plot(np.arange(len(test_acc_list_error_0)),np.asarray(test_acc_list_error_0),label = "test(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_error_5)),np.asarray(test_acc_list_error_5),label = "test(error_raito=0.05)")
plt.plot(np.arange(len(test_acc_list_error_10)),np.asarray(test_acc_list_error_10),label = "test(error_raito=0.10)")
plt.plot(np.arange(len(test_acc_list_error_15)),np.asarray(test_acc_list_error_15),label = "test(error_raito=0.15)")
plt.plot(np.arange(len(test_acc_list_error_20)),np.asarray(test_acc_list_error_20),label = "test(error_raito=0.20)")
plt.plot(np.arange(len(test_acc_list_error_25)),np.asarray(test_acc_list_error_25),label = "test(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("test data")

plt.legend()
plt.show()

# %% [markdown]
# ### ノイズ耐性について調べる

# %%
### まずは層を深くしてみる

optimizer_sgd_2layer = SGD(0.5)
optimizer_sgd_3layer = SGD(0.5)
optimizer_sgd_4layer = SGD(0.5)
optimizer_sgd_5layer = SGD(0.5)
optimizer_sgd_2layer_error_25 = SGD(0.5)
optimizer_sgd_3layer_error_25 = SGD(0.5)
optimizer_sgd_4layer_error_25 = SGD(0.5)
optimizer_sgd_5layer_error_25 = SGD(0.5)

model_2layer = MLP([Affine(784,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_3layer = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_4layer = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_5layer = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_2layer_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_3layer_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_4layer_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_5layer_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])

optimizer_sgd_2layer.set(model_2layer)
optimizer_sgd_3layer.set(model_3layer)
optimizer_sgd_4layer.set(model_4layer)
optimizer_sgd_5layer.set(model_5layer)
optimizer_sgd_2layer_error_25.set(model_2layer_error_25)
optimizer_sgd_3layer_error_25.set(model_3layer_error_25)
optimizer_sgd_4layer_error_25.set(model_4layer_error_25)
optimizer_sgd_5layer_error_25.set(model_5layer_error_25)

# %%
### 訓練開始
train_loss_list_2layer, train_acc_list_2layer, test_loss_list_2layer, test_acc_list_2layer = train(model_2layer, optimizer_sgd_2layer,error_ratio=0)
train_loss_list_3layer, train_acc_list_3layer, test_loss_list_3layer, test_acc_list_3layer = train(model_3layer, optimizer_sgd_3layer,error_ratio=0)
train_loss_list_4layer, train_acc_list_4layer, test_loss_list_4layer, test_acc_list_4layer = train(model_4layer, optimizer_sgd_4layer,error_ratio=0)
train_loss_list_5layer, train_acc_list_5layer, test_loss_list_5layer, test_acc_list_5layer = train(model_5layer, optimizer_sgd_5layer,error_ratio=0)

train_loss_list_2layer_error_25, train_acc_list_2layer_error_25, test_loss_list_2layer_error_25, test_acc_list_2layer_error_25= train(model_2layer_error_25, optimizer_sgd_2layer_error_25,error_ratio=0.25)
train_loss_list_3layer_error_25, train_acc_list_3layer_error_25, test_loss_list_3layer_error_25, test_acc_list_3layer_error_25= train(model_3layer_error_25, optimizer_sgd_3layer_error_25,error_ratio=0.25)
train_loss_list_4layer_error_25, train_acc_list_4layer_error_25, test_loss_list_4layer_error_25, test_acc_list_4layer_error_25= train(model_4layer_error_25, optimizer_sgd_4layer_error_25,error_ratio=0.25)
train_loss_list_5layer_error_25, train_acc_list_5layer_error_25, test_loss_list_5layer_error_25, test_acc_list_5layer_error_25= train(model_5layer_error_25, optimizer_sgd_5layer_error_25,error_ratio=0.25)

# %%
### 層を深くしてみた時のtrainデータの訓練結果

plt.plot(np.arange(len(train_acc_list_2layer)),np.asarray(train_acc_list_2layer),label = "2layer(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_3layer)),np.asarray(train_acc_list_3layer),label = "3layer(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_4layer)),np.asarray(train_acc_list_4layer),label = "4layer(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_5layer)),np.asarray(train_acc_list_5layer),label = "5layer(error_raito=0.00)")


plt.plot(np.arange(len(train_acc_list_2layer_error_25)),np.asarray(train_acc_list_2layer_error_25),label = "2layer(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_3layer_error_25)),np.asarray(train_acc_list_3layer_error_25),label = "3layer(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_4layer_error_25)),np.asarray(train_acc_list_4layer_error_25),label = "4layer(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_5layer_error_25)),np.asarray(train_acc_list_5layer_error_25),label = "5layer(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("train data")

plt.legend()
plt.show()

# %%
### 層を深くしてみた時のtrainデータの訓練結果

plt.plot(np.arange(len(test_acc_list_2layer)),np.asarray(test_acc_list_2layer),label = "2layer(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_3layer)),np.asarray(test_acc_list_3layer),label = "3layer(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_4layer)),np.asarray(test_acc_list_4layer),label = "4layer(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_5layer)),np.asarray(test_acc_list_5layer),label = "5layer(error_raito=0.00)")

plt.plot(np.arange(len(test_acc_list_2layer_error_25)),np.asarray(test_acc_list_2layer_error_25),label = "2layer(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_3layer_error_25)),np.asarray(test_acc_list_3layer_error_25),label = "3layer(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_4layer_error_25)),np.asarray(test_acc_list_4layer_error_25),label = "4layer(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_5layer_error_25)),np.asarray(test_acc_list_5layer_error_25),label = "5layer(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("test data")

plt.legend()
plt.show()

# %%
### 層を深くしてみた時のtrainデータの訓練結果

plt.plot(np.arange(len(test_acc_list_2layer)),np.asarray(test_acc_list_2layer),label = "2layer(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_3layer)),np.asarray(test_acc_list_3layer),label = "test3layer(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_4layer)),np.asarray(test_acc_list_4layer),label = "4layer(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_5layer)),np.asarray(test_acc_list_5layer),label = "test5layer(error_raito=0.00)")

plt.plot(np.arange(len(test_acc_list_2layer_error_25)),np.asarray(test_acc_list_2layer_error_25),label = "2layer(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_3layer_error_25)),np.asarray(test_acc_list_3layer_error_25),label = "test3layer(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_4layer_error_25)),np.asarray(test_acc_list_4layer_error_25),label = "4layer(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_5layer_error_25)),np.asarray(test_acc_list_5layer_error_25),label = "test5layer(error_raito=0.25)")

plt.plot(np.arange(len(train_acc_list_2layer)),np.asarray(train_acc_list_2layer),label = "2layer(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_3layer)),np.asarray(train_acc_list_3layer),label = "3layer(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_4layer)),np.asarray(train_acc_list_4layer),label = "4layer(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_5layer)),np.asarray(train_acc_list_5layer),label = "5layer(error_raito=0.00)")

plt.plot(np.arange(len(train_acc_list_2layer_error_25)),np.asarray(train_acc_list_2layer_error_25),label = "2layer(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_3layer_error_25)),np.asarray(train_acc_list_3layer_error_25),label = "3layer(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_4layer_error_25)),np.asarray(train_acc_list_4layer_error_25),label = "4layer(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_5layer_error_25)),np.asarray(train_acc_list_5layer_error_25),label = "5layer(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("test data")

plt.legend()
plt.show()

# %%
dif_3layer_error_0 = np.asarray(train_acc_list_3layer) - np.asarray(test_acc_list_3layer)
dif_5layer_error_0 = np.asarray(train_acc_list_5layer) - np.asarray(test_acc_list_5layer)
dif_3layer_error_25 = np.asarray(train_acc_list_3layer_error_25) - np.asarray(test_acc_list_3layer_error_25)
dif_5layer_error_25 = np.asarray(train_acc_list_5layer_error_25) - np.asarray(test_acc_list_5layer_error_25)

# %%
plt.plot(np.arange(dif_3layer_error_0.shape[0]),dif_3layer_error_0,label = "3layer(error_raito=0.00)")
plt.plot(np.arange(dif_5layer_error_0.shape[0]),dif_5layer_error_0,label = "5layer(error_raito=0.00)")
plt.plot(np.arange(dif_3layer_error_25.shape[0]),dif_3layer_error_25,label = "3layer(error_raito=0.25)")
plt.plot(np.arange(dif_5layer_error_25.shape[0]),dif_5layer_error_25,label = "5layer(error_raito=0.25)")

plt.legend()
plt.show()

# %% [markdown]
# ↑は訓練データのaccuracyとテストデータのaccurayの差をグラフ化したものである。

# %% [markdown]
# ### 層を深くすることで得られた考察
#
# 入力データに誤差を入れた際、trainデータに対する正解率とtestデータに対する正解率の差は、層を深くすればするほど大きくなった。
# これは層を深くすればするほど表現力が上がるため、ノイズまで正確に表現できるようになってしまい、過学習のような状態になってしまっているのだと考えれる。

# %% [markdown]
# ### 学習係数を変更したときのノイズ耐性

# %%
### 学習係数を変更する

optimizer_sgd_05 = SGD(0.5)
optimizer_sgd_01 = SGD(0.1)
optimizer_sgd_001 = SGD(0.01)
optimizer_sgd_0001 = SGD(0.001)
optimizer_sgd_05_error_25 = SGD(0.5)
optimizer_sgd_01_error_25 = SGD(0.1)
optimizer_sgd_001_error_25 = SGD(0.01)
optimizer_sgd_0001_error_25 = SGD(0.0001)

model_05 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_01 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_001 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_0001 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_05_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_01_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_001_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_0001_error_25 = MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])

optimizer_sgd_05.set(model_05)
optimizer_sgd_01.set(model_01)
optimizer_sgd_001.set(model_001)
optimizer_sgd_0001.set(model_0001)
optimizer_sgd_05_error_25.set(model_05_error_25)
optimizer_sgd_01_error_25.set(model_01_error_25)
optimizer_sgd_001_error_25.set(model_001_error_25)
optimizer_sgd_0001_error_25.set(model_0001_error_25)

# %%
### 訓練開始
train_loss_list_05, train_acc_list_05, test_loss_list_05, test_acc_list_05 = train(model_05, optimizer_sgd_05,error_ratio=0)
train_loss_list_01, train_acc_list_01, test_loss_list_01, test_acc_list_01 = train(model_01, optimizer_sgd_01,error_ratio=0)
train_loss_list_001, train_acc_list_001, test_loss_list_001, test_acc_list_001 = train(model_001, optimizer_sgd_001,error_ratio=0)
train_loss_list_0001, train_acc_list_0001, test_loss_list_0001, test_acc_list_0001 = train(model_0001, optimizer_sgd_0001,error_ratio=0)

train_loss_list_05_error_25, train_acc_list_05_error_25, test_loss_list_05_error_25, test_acc_list_05_error_25 = train(model_05_error_25, optimizer_sgd_05_error_25,error_ratio=0.25)
train_loss_list_01_error_25, train_acc_list_01_error_25, test_loss_list_01_error_25, test_acc_list_01_error_25 = train(model_01_error_25, optimizer_sgd_01_error_25,error_ratio=0.25)
train_loss_list_001_error_25, train_acc_list_001_error_25, test_loss_list_001_error_25, test_acc_list_001_error_25 = train(model_001_error_25, optimizer_sgd_001_error_25,error_ratio=0.25)
train_loss_list_0001_error_25, train_acc_list_0001_error_25, test_loss_list_0001_error_25, test_acc_list_0001_error_25 = train(model_0001_error_25, optimizer_sgd_0001_error_25,error_ratio=0.25)

# %%
### 学習係数を変えてみたときの違い

plt.plot(np.arange(len(train_acc_list_05)),np.asarray(test_acc_list_05),label = "lr=0.5(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_01)),np.asarray(train_acc_list_01),label = "lr=0.1(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_001)),np.asarray(test_acc_list_001),label = "lr=0.01(error_raito=0.00)")
plt.plot(np.arange(len(train_acc_list_0001)),np.asarray(train_acc_list_0001),label = "lr=0.001(error_raito=0.00)")

plt.plot(np.arange(len(train_acc_list_05_error_25)),np.asarray(train_acc_list_05_error_25),label = "lr=0.5(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_01_error_25)),np.asarray(train_acc_list_01_error_25),label = "lr=0.1(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_001_error_25)),np.asarray(train_acc_list_001_error_25),label = "lr=0.01(error_raito=0.25)")
plt.plot(np.arange(len(train_acc_list_0001_error_25)),np.asarray(train_acc_list_0001_error_25),label = "lr=0.001(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("train data")

plt.legend()
plt.show()

# %%
### 学習係数を変えてみたときの違い

plt.plot(np.arange(len(test_acc_list_05)),np.asarray(test_acc_list_2layer),label = "lr=0.5(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_01)),np.asarray(test_acc_list_01),label = "lr=0.1(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_001)),np.asarray(test_acc_list_4layer),label = "lr=0.01(error_raito=0.00)")
plt.plot(np.arange(len(test_acc_list_0001)),np.asarray(test_acc_list_0001),label = "lr=0.001(error_raito=0.00)")

plt.plot(np.arange(len(test_acc_list_05_error_25)),np.asarray(test_acc_list_05_error_25),label = "lr=0.5(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_01_error_25)),np.asarray(test_acc_list_01_error_25),label = "lr=0.1(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_001_error_25)),np.asarray(test_acc_list_001_error_25),label = "lr=0.01(error_raito=0.25)")
plt.plot(np.arange(len(test_acc_list_0001_error_25)),np.asarray(test_acc_list_0001_error_25),label = "lr=0.001(error_raito=0.25)")

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("test data")

plt.legend()
plt.show()

# %%
dif_05_error_0 = np.asarray(train_acc_list_05) - np.asarray(test_acc_list_05)
dif_01_error_0 = np.asarray(train_acc_list_01) - np.asarray(test_acc_list_01)
dif_001_error_0 = np.asarray(train_acc_list_001) - np.asarray(test_acc_list_001)
dif_0001_error_0 = np.asarray(train_acc_list_0001) - np.asarray(test_acc_list_0001)

dif_05_error_25 = np.asarray(train_acc_list_05_error_25) - np.asarray(test_acc_list_05_error_25)
dif_01_error_25 = np.asarray(train_acc_list_01_error_25) - np.asarray(test_acc_list_01_error_25)
dif_001_error_25 = np.asarray(train_acc_list_001_error_25) - np.asarray(test_acc_list_001_error_25)
dif_0001_error_25 = np.asarray(train_acc_list_0001_error_25) - np.asarray(test_acc_list_0001_error_25)

# %%
plt.plot(np.arange(dif_05_error_0.shape[0]),dif_05_error_0,label = "lr=0.5(error_raito=0.00)")
plt.plot(np.arange(dif_01_error_0.shape[0]),dif_01_error_0,label = "lr=0.1(error_raito=0.00)")
plt.plot(np.arange(dif_001_error_0.shape[0]),dif_001_error_0,label = "lr=0.01(error_raito=0.00)")
plt.plot(np.arange(dif_0001_error_0.shape[0]),dif_0001_error_0,label = "lr=0.001(error_raito=0.00)")


plt.plot(np.arange(dif_05_error_25.shape[0]),dif_05_error_25,label = "lr=0.5(error_raito=0.25)")
plt.plot(np.arange(dif_01_error_25.shape[0]),dif_01_error_25,label = "lr=0.1(error_raito=0.25)")
plt.plot(np.arange(dif_001_error_25.shape[0]),dif_001_error_25,label = "lr=0.01(error_raito=0.25)")
plt.plot(np.arange(dif_0001_error_25.shape[0]),dif_0001_error_25,label = "lr=0.001(error_raito=0.25)")

plt.legend()
plt.show()

# %% [markdown]
# ### ニューロン数の増減

# %%
optimizer_sgd_2000 = SGD(0.1)
optimizer_sgd_1000 = SGD(0.1)
optimizer_sgd_500 = SGD(0.1)
optimizer_sgd_100 = SGD(0.1)

model_2000= MLP([Affine(784,2000),Sigmoid(),Affine(2000,2000),Sigmoid(),Affine(2000,10),Softmax()])
model_1000= MLP([Affine(784,1000),Sigmoid(),Affine(1000,1000),Sigmoid(),Affine(1000,10),Softmax()])
model_500= MLP([Affine(784,500),Sigmoid(),Affine(500,500),Sigmoid(),Affine(500,10),Softmax()])
model_100= MLP([Affine(784,100),Sigmoid(),Affine(100,100),Sigmoid(),Affine(100,10),Softmax()])

optimizer_sgd_2000.set(model_2000)
optimizer_sgd_1000.set(model_1000)
optimizer_sgd_500.set(model_500)
optimizer_sgd_100.set(model_100)

# %%
### 誤差による結果を求める
train_loss_list_2000, train_acc_list_2000, test_loss_list_2000, test_acc_list_2000 = train(model_2000, optimizer_sgd_2000,error_ratio=0)
train_loss_list_1000, train_acc_list_1000, test_loss_list_1000, test_acc_list_1000 = train(model_1000, optimizer_sgd_1000,error_ratio=0)
train_loss_list_500, train_acc_list_500, test_loss_list_500, test_acc_list_500 = train(model_500, optimizer_sgd_500,error_ratio=0)
train_loss_list_100, train_acc_list_100, test_loss_list_100, test_acc_list_100 = train(model_100, optimizer_sgd_100,error_ratio=0)

# %%
### trainデータの訓練結果

plt.plot(np.arange(len(train_acc_list_2000)),np.asarray(train_acc_list_2000),label = "train_2000")
plt.plot(np.arange(len(train_acc_list_1000)),np.asarray(train_acc_list_1000),label = "train_1000")
plt.plot(np.arange(len(train_acc_list_500)),np.asarray(train_acc_list_500),label = "train_500")
plt.plot(np.arange(len(train_acc_list_100)),np.asarray(train_acc_list_100),label = "train_100")

plt.xlabel("epoch")
plt.ylabel("accuracy")

plt.legend()
plt.show()

# %%
plt.plot(np.arange(len(test_acc_list_2000)),np.asarray(test_acc_list_2000),label = "test_2000")
plt.plot(np.arange(len(test_acc_list_1000)),np.asarray(test_acc_list_1000),label = "test_1000")
plt.plot(np.arange(len(test_acc_list_500)),np.asarray(test_acc_list_500),label = "test_500")
plt.plot(np.arange(len(test_acc_list_100)),np.asarray(test_acc_list_100),label = "test_100")

plt.xlabel("epoch")
plt.ylabel("accuracy")

plt.legend()
plt.show()
